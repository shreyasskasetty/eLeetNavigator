# %%
from transformers import BertTokenizer, BertModel
import torch
from scipy.spatial.distance import cosine

def get_bert_embedding(sentence, model, tokenizer):
    """Generate BERT embeddings for a given sentence."""
    # Tokenize the sentence and convert to tensor
    input_ids = tokenizer.encode(sentence, return_tensors='pt', add_special_tokens=True, max_length=512, truncation=True)
    with torch.no_grad():
        # Generate embeddings for the sentence
        outputs = model(input_ids)
    # Use the average of all token embeddings as the sentence representation
    embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings

def calculate_similarity(embedding1, embedding2):
    """Calculate cosine similarity between two embeddings."""
    # Cosine similarity calculation
    similarity = 1 - cosine(embedding1.numpy(), embedding2.numpy())
    return similarity

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import pandas as pd

# %%
prob_description = pd.read_json('../data/final-prob-desc.json')

# %%
prob_description
# Out:
#                                                      id  \
# 0                       3103. Find Trending Hashtags II
# 1                    3102. Minimize Manhattan Distances
# 2                     3101. Count Alternating Subarrays
# 3                                3100. Water Bottles II
# 4                                  3099. Harshad Number
# ...                                                 ...
# 3098                   5. Longest Palindromic Substring
# 3099                     4. Median of Two Sorted Arrays
# 3100  3. Longest Substring Without Repeating Characters
# 3101                                 2. Add Two Numbers
# 3102                                         1. Two Sum
#
#                                                    desc
# 0     Table: Tweets\n\n+-------------+---------+\n| ...
# 1     You are given a 0-indexed array points represe...
# 2     You are given a binary array nums.\n\nWe call ...
# 3     You are given two integers numBottles and numE...
# 4     An integer divisible by the sum of its digits ...
# ...                                                 ...
# 3098  Given a string s, return the longest palindrom...
# 3099  Given two sorted arrays nums1 and nums2 of siz...
# 3100  Given a string s, find the length of the longe...
# 3101  You are given two non-empty linked lists repre...
# 3102  Given an array of integers nums and an integer...
#
# [3103 rows x 2 columns]

# %%
prod_id = prob_description['id'].unique()
prod_id.sort()

# %%
import pandas as pd
import numpy as np

# Create a random matrix or any data you wish to use, ensuring the dimensions match the number of labels
data = np.zeros((len(prod_id), len(prod_id)))

# Create the DataFrame with the same labels for rows and columns
df = pd.DataFrame(data, index=prod_id, columns=prod_id)

# %%
import math
import traceback

# %%
prob_data = pd.read_csv('../data/final-problem-data.csv')

# %%
prob_data['topics'][prob_data['id'] == '10. Regular Expression Matching'].item()
# Out:
# 'String,Dynamic Programming,Recursion'

# %%
import re
embed_token = pd.DataFrame(index=prod_id, columns=['token'])

for i in range(len(prod_id)):
    sentence = prob_description[prob_description['id'] == prod_id[i]]['desc']
    sentence = sentence.iloc[0]
    try:
        if sentence is not None:
            index = sentence.find('Example 1')
            if index == -1:
                desc = sentence
            else:
                desc = sentence[0:index]
            desc = re.sub("\\n", ' ', desc)
            desc = re.sub("\s+", " ", desc) 
            topics =prob_data['topics'][prob_data['id'] == prod_id[i]]
            if not topics.empty and type(topics.item()) == str:
                desc = desc + " topics: [" + topics.item() + "]"                

            token = get_bert_embedding(desc, model, tokenizer)
            embed_token.loc[prod_id[i]] = [token[0]]
        else:
            embed_token.loc[prod_id[i]] = math.nan
            
    except Exception as err:
        print(prod_id[i])
        print(err)
        print(traceback.format_exc())
        break

# %%
type('ab') == str
# Out:
# True

# %%
for i in range(len(prod_id)):
    embed_1 = embed_token.loc[prod_id[i]][0]
    if embed_1 is math.nan:
        continue

    for j in range(i, len(prod_id)):
        embed_2 = embed_token.loc[prod_id[j]][0]
        if embed_2 is math.nan:
            continue
        simi = calculate_similarity(embed_1, embed_2)
        df.loc[prod_id[i]].loc[prod_id[j]] = simi
        df.loc[prod_id[j]].loc[prod_id[i]] = simi

# %%
import pandas as pd
df = pd.read_csv('../data/cos-sim-desc-and-topics.csv').set_index('Unnamed: 0')

# %%
df
# Out:
#                                                 1. Two Sum  \
# Unnamed: 0
# 1. Two Sum                                        1.000000
# 10. Regular Expression Matching                   0.895608
# 100. Same Tree                                    0.000000
# 1000. Minimum Cost to Merge Stones                0.888748
# 1001. Grid Illumination                           0.864339
# ...                                                    ...
# 995. Minimum Number of K Consecutive Bit Flips    0.921225
# 996. Number of Squareful Arrays                   0.910534
# 997. Find the Town Judge                          0.834872
# 998. Maximum Binary Tree II                       0.885692
# 999. Available Captures for Rook                  0.767589
#
#                                                 10. Regular Expression Matching  \
# Unnamed: 0
# 1. Two Sum                                                             0.895608
# 10. Regular Expression Matching                                        1.000000
# 100. Same Tree                                                         0.000000
# 1000. Minimum Cost to Merge Stones                                     0.840534
# 1001. Grid Illumination                                                0.848167
# ...                                                                         ...
# 995. Minimum Number of K Consecutive Bit Flips                         0.895335
# 996. Number of Squareful Arrays                                        0.889189
# 997. Find the Town Judge                                               0.837857
# 998. Maximum Binary Tree II                                            0.896396
# 999. Available Captures for Rook                                       0.766480
#
#                                                 100. Same Tree  \
# Unnamed: 0
# 1. Two Sum                                                 0.0
# 10. Regular Expression Matching                            0.0
# 100. Same Tree                                             0.0
# 1000. Minimum Cost to Merge Stones                         0.0
# 1001. Grid Illumination                                    0.0
# ...                                                        ...
# 995. Minimum Number of K Consecutive Bit Flips             0.0
# 996. Number of Squareful Arrays                            0.0
# 997. Find the Town Judge                                   0.0
# 998. Maximum Binary Tree II                                0.0
# 999. Available Captures for Rook                           0.0
#
#                                                 1000. Minimum Cost to Merge Stones  \
# Unnamed: 0
# 1. Two Sum                                                                0.888748
# 10. Regular Expression Matching                                           0.840534
# 100. Same Tree                                                            0.000000
# 1000. Minimum Cost to Merge Stones                                        1.000000
# 1001. Grid Illumination                                                   0.884365
# ...                                                                            ...
# 995. Minimum Number of K Consecutive Bit Flips                            0.897370
# 996. Number of Squareful Arrays                                           0.886814
# 997. Find the Town Judge                                                  0.864439
# 998. Maximum Binary Tree II                                               0.873303
# 999. Available Captures for Rook                                          0.866757
#
#                                                 1001. Grid Illumination  \
# Unnamed: 0
# 1. Two Sum                                                     0.864339
# 10. Regular Expression Matching                                0.848167
# 100. Same Tree                                                 0.000000
# 1000. Minimum Cost to Merge Stones                             0.884365
# 1001. Grid Illumination                                        1.000000
# ...                                                                 ...
# 995. Minimum Number of K Consecutive Bit Flips                 0.887779
# 996. Number of Squareful Arrays                                0.872419
# 997. Find the Town Judge                                       0.891561
# 998. Maximum Binary Tree II                                    0.899063
# 999. Available Captures for Rook                               0.853852
#
#                                                 1002. Find Common Characters  \
# Unnamed: 0
# 1. Two Sum                                                          0.927714
# 10. Regular Expression Matching                                     0.912762
# 100. Same Tree                                                      0.000000
# 1000. Minimum Cost to Merge Stones                                  0.840507
# 1001. Grid Illumination                                             0.828887
# ...                                                                      ...
# 995. Minimum Number of K Consecutive Bit Flips                      0.890102
# 996. Number of Squareful Arrays                                     0.869704
# 997. Find the Town Judge                                            0.803245
# 998. Maximum Binary Tree II                                         0.850834
# 999. Available Captures for Rook                                    0.742720
#
#                                                 1003. Check If Word Is Valid After Substitutions  \
# Unnamed: 0
# 1. Two Sum                                                                              0.883680
# 10. Regular Expression Matching                                                         0.912532
# 100. Same Tree                                                                          0.000000
# 1000. Minimum Cost to Merge Stones                                                      0.831024
# 1001. Grid Illumination                                                                 0.843550
# ...                                                                                          ...
# 995. Minimum Number of K Consecutive Bit Flips                                          0.894897
# 996. Number of Squareful Arrays                                                         0.888505
# 997. Find the Town Judge                                                                0.840025
# 998. Maximum Binary Tree II                                                             0.915702
# 999. Available Captures for Rook                                                        0.746199
#
#                                                 1004. Max Consecutive Ones III  \
# Unnamed: 0
# 1. Two Sum                                                            0.932714
# 10. Regular Expression Matching                                       0.907472
# 100. Same Tree                                                        0.000000
# 1000. Minimum Cost to Merge Stones                                    0.877274
# 1001. Grid Illumination                                               0.850859
# ...                                                                        ...
# 995. Minimum Number of K Consecutive Bit Flips                        0.942432
# 996. Number of Squareful Arrays                                       0.929309
# 997. Find the Town Judge                                              0.808819
# 998. Maximum Binary Tree II                                           0.879805
# 999. Available Captures for Rook                                      0.763630
#
#                                                 1005. Maximize Sum Of Array After K Negations  \
# Unnamed: 0
# 1. Two Sum                                                                           0.941823
# 10. Regular Expression Matching                                                      0.900435
# 100. Same Tree                                                                       0.000000
# 1000. Minimum Cost to Merge Stones                                                   0.903316
# 1001. Grid Illumination                                                              0.881308
# ...                                                                                       ...
# 995. Minimum Number of K Consecutive Bit Flips                                       0.948633
# 996. Number of Squareful Arrays                                                      0.926274
# 997. Find the Town Judge                                                             0.852248
# 998. Maximum Binary Tree II                                                          0.910571
# 999. Available Captures for Rook                                                     0.793056
#
#                                                 1006. Clumsy Factorial  ...  \
# Unnamed: 0                                                              ...
# 1. Two Sum                                                         0.0  ...
# 10. Regular Expression Matching                                    0.0  ...
# 100. Same Tree                                                     0.0  ...
# 1000. Minimum Cost to Merge Stones                                 0.0  ...
# 1001. Grid Illumination                                            0.0  ...
# ...                                                                ...  ...
# 995. Minimum Number of K Consecutive Bit Flips                     0.0  ...
# 996. Number of Squareful Arrays                                    0.0  ...
# 997. Find the Town Judge                                           0.0  ...
# 998. Maximum Binary Tree II                                        0.0  ...
# 999. Available Captures for Rook                                   0.0  ...
#
#                                                 990. Satisfiability of Equality Equations  \
# Unnamed: 0
# 1. Two Sum                                                                       0.918070
# 10. Regular Expression Matching                                                  0.924634
# 100. Same Tree                                                                   0.000000
# 1000. Minimum Cost to Merge Stones                                               0.868253
# 1001. Grid Illumination                                                          0.878815
# ...                                                                                   ...
# 995. Minimum Number of K Consecutive Bit Flips                                   0.900891
# 996. Number of Squareful Arrays                                                  0.909331
# 997. Find the Town Judge                                                         0.859747
# 998. Maximum Binary Tree II                                                      0.898291
# 999. Available Captures for Rook                                                 0.777696
#
#                                                 991. Broken Calculator  \
# Unnamed: 0
# 1. Two Sum                                                    0.912370
# 10. Regular Expression Matching                               0.872154
# 100. Same Tree                                                0.000000
# 1000. Minimum Cost to Merge Stones                            0.892897
# 1001. Grid Illumination                                       0.891041
# ...                                                                ...
# 995. Minimum Number of K Consecutive Bit Flips                0.922578
# 996. Number of Squareful Arrays                               0.893504
# 997. Find the Town Judge                                      0.860112
# 998. Maximum Binary Tree II                                   0.883450
# 999. Available Captures for Rook                              0.823507
#
#                                                 992. Subarrays with K Different Integers  \
# Unnamed: 0
# 1. Two Sum                                                                      0.914368
# 10. Regular Expression Matching                                                 0.869125
# 100. Same Tree                                                                  0.000000
# 1000. Minimum Cost to Merge Stones                                              0.898991
# 1001. Grid Illumination                                                         0.890252
# ...                                                                                  ...
# 995. Minimum Number of K Consecutive Bit Flips                                  0.942147
# 996. Number of Squareful Arrays                                                 0.941777
# 997. Find the Town Judge                                                        0.841439
# 998. Maximum Binary Tree II                                                     0.896083
# 999. Available Captures for Rook                                                0.803742
#
#                                                 993. Cousins in Binary Tree  \
# Unnamed: 0
# 1. Two Sum                                                         0.861026
# 10. Regular Expression Matching                                    0.846004
# 100. Same Tree                                                     0.000000
# 1000. Minimum Cost to Merge Stones                                 0.845793
# 1001. Grid Illumination                                            0.857257
# ...                                                                     ...
# 995. Minimum Number of K Consecutive Bit Flips                     0.876943
# 996. Number of Squareful Arrays                                    0.866009
# 997. Find the Town Judge                                           0.850852
# 998. Maximum Binary Tree II                                        0.886525
# 999. Available Captures for Rook                                   0.781644
#
#                                                 994. Rotting Oranges  \
# Unnamed: 0
# 1. Two Sum                                                  0.893720
# 10. Regular Expression Matching                             0.850359
# 100. Same Tree                                              0.000000
# 1000. Minimum Cost to Merge Stones                          0.905554
# 1001. Grid Illumination                                     0.909108
# ...                                                              ...
# 995. Minimum Number of K Consecutive Bit Flips              0.905513
# 996. Number of Squareful Arrays                             0.856419
# 997. Find the Town Judge                                    0.882097
# 998. Maximum Binary Tree II                                 0.868519
# 999. Available Captures for Rook                            0.854266
#
#                                                 995. Minimum Number of K Consecutive Bit Flips  \
# Unnamed: 0
# 1. Two Sum                                                                            0.921225
# 10. Regular Expression Matching                                                       0.895335
# 100. Same Tree                                                                        0.000000
# 1000. Minimum Cost to Merge Stones                                                    0.897370
# 1001. Grid Illumination                                                               0.887779
# ...                                                                                        ...
# 995. Minimum Number of K Consecutive Bit Flips                                        1.000000
# 996. Number of Squareful Arrays                                                       0.931069
# 997. Find the Town Judge                                                              0.849734
# 998. Maximum Binary Tree II                                                           0.915021
# 999. Available Captures for Rook                                                      0.802484
#
#                                                 996. Number of Squareful Arrays  \
# Unnamed: 0
# 1. Two Sum                                                             0.910534
# 10. Regular Expression Matching                                        0.889189
# 100. Same Tree                                                         0.000000
# 1000. Minimum Cost to Merge Stones                                     0.886814
# 1001. Grid Illumination                                                0.872419
# ...                                                                         ...
# 995. Minimum Number of K Consecutive Bit Flips                         0.931069
# 996. Number of Squareful Arrays                                        1.000000
# 997. Find the Town Judge                                               0.826660
# 998. Maximum Binary Tree II                                            0.904263
# 999. Available Captures for Rook                                       0.773799
#
#                                                 997. Find the Town Judge  \
# Unnamed: 0
# 1. Two Sum                                                      0.834872
# 10. Regular Expression Matching                                 0.837857
# 100. Same Tree                                                  0.000000
# 1000. Minimum Cost to Merge Stones                              0.864439
# 1001. Grid Illumination                                         0.891561
# ...                                                                  ...
# 995. Minimum Number of K Consecutive Bit Flips                  0.849734
# 996. Number of Squareful Arrays                                 0.826660
# 997. Find the Town Judge                                        1.000000
# 998. Maximum Binary Tree II                                     0.881366
# 999. Available Captures for Rook                                0.849263
#
#                                                 998. Maximum Binary Tree II  \
# Unnamed: 0
# 1. Two Sum                                                         0.885692
# 10. Regular Expression Matching                                    0.896396
# 100. Same Tree                                                     0.000000
# 1000. Minimum Cost to Merge Stones                                 0.873303
# 1001. Grid Illumination                                            0.899063
# ...                                                                     ...
# 995. Minimum Number of K Consecutive Bit Flips                     0.915021
# 996. Number of Squareful Arrays                                    0.904263
# 997. Find the Town Judge                                           0.881366
# 998. Maximum Binary Tree II                                        1.000000
# 999. Available Captures for Rook                                   0.794289
#
#                                                 999. Available Captures for Rook
# Unnamed: 0
# 1. Two Sum                                                              0.767589
# 10. Regular Expression Matching                                         0.766480
# 100. Same Tree                                                          0.000000
# 1000. Minimum Cost to Merge Stones                                      0.866757
# 1001. Grid Illumination                                                 0.853852
# ...                                                                          ...
# 995. Minimum Number of K Consecutive Bit Flips                          0.802484
# 996. Number of Squareful Arrays                                         0.773799
# 997. Find the Town Judge                                                0.849263
# 998. Maximum Binary Tree II                                             0.794289
# 999. Available Captures for Rook                                        1.000000
#
# [3103 rows x 3103 columns]

# %%
next = df['285. Inorder Successor in BST'].nlargest(5)

for i, v in next.items():
    print(f"Index: {i}, Value: {v}")
# Out:
# Index: 285. Inorder Successor in BST, Value: 1.0
# Index: 1602. Find Nearest Right Node in Binary Tree, Value: 0.9642816185951232
# Index: 1448. Count Good Nodes in Binary Tree, Value: 0.9606204032897948
# Index: 700. Search in a Binary Search Tree, Value: 0.9605814814567566
# Index: 508. Most Frequent Subtree Sum, Value: 0.9605518579483032

# %%
[
    {
        "name" : "Because you solved Content ",
        "list" : [1, 2 ,3]
    },
    {
        "name" : "beca ...",
        "list" : [4, 5, 6]
    }
]

# %%
if "sane" == "sane":
    print("macha")
# Out:
# macha

# %%
df = pd.read_csv('../data/cos-sim-desc-and-topics.csv').set_index('Unnamed: 0')

# %%
df.columns
# Out:
# Index(['1. Two Sum', '10. Regular Expression Matching', '100. Same Tree',
#        '1000. Minimum Cost to Merge Stones', '1001. Grid Illumination',
#        '1002. Find Common Characters',
#        '1003. Check If Word Is Valid After Substitutions',
#        '1004. Max Consecutive Ones III',
#        '1005. Maximize Sum Of Array After K Negations',
#        '1006. Clumsy Factorial',
#        ...
#        '990. Satisfiability of Equality Equations', '991. Broken Calculator',
#        '992. Subarrays with K Different Integers',
#        '993. Cousins in Binary Tree', '994. Rotting Oranges',
#        '995. Minimum Number of K Consecutive Bit Flips',
#        '996. Number of Squareful Arrays', '997. Find the Town Judge',
#        '998. Maximum Binary Tree II', '999. Available Captures for Rook'],
#       dtype='object', length=3103)

# %%
import re
new_index = []
map = {}
for col in df.columns:
    id = re.sub(r'^\d+\.\s*', '', col)
    id = id.lower()
    id = id.strip()
    id = id.replace(" ", "-")
    map[col] = id
    new_index.append(id)

# %%
import numpy as np
data = np.zeros((len(new_index), len(new_index)))
new_df = pd.DataFrame(data,columns=new_index, index=new_index)

# %%
for col in df.columns:
    new_df[map[col]] = df[col].to_numpy()

# %%
new_df['two-sum'] = df['1. Two Sum'].to_numpy()

# %%
new_df
# Out:
#                                             two-sum  \
# two-sum                                    1.000000
# regular-expression-matching                0.895608
# same-tree                                  0.000000
# minimum-cost-to-merge-stones               0.888748
# grid-illumination                          0.864339
# ...                                             ...
# minimum-number-of-k-consecutive-bit-flips  0.921225
# number-of-squareful-arrays                 0.910534
# find-the-town-judge                        0.834872
# maximum-binary-tree-ii                     0.885692
# available-captures-for-rook                0.767589
#
#                                            regular-expression-matching  \
# two-sum                                                       0.895608
# regular-expression-matching                                   1.000000
# same-tree                                                     0.000000
# minimum-cost-to-merge-stones                                  0.840534
# grid-illumination                                             0.848167
# ...                                                                ...
# minimum-number-of-k-consecutive-bit-flips                     0.895335
# number-of-squareful-arrays                                    0.889189
# find-the-town-judge                                           0.837857
# maximum-binary-tree-ii                                        0.896396
# available-captures-for-rook                                   0.766480
#
#                                            same-tree  \
# two-sum                                          0.0
# regular-expression-matching                      0.0
# same-tree                                        0.0
# minimum-cost-to-merge-stones                     0.0
# grid-illumination                                0.0
# ...                                              ...
# minimum-number-of-k-consecutive-bit-flips        0.0
# number-of-squareful-arrays                       0.0
# find-the-town-judge                              0.0
# maximum-binary-tree-ii                           0.0
# available-captures-for-rook                      0.0
#
#                                            minimum-cost-to-merge-stones  \
# two-sum                                                        0.888748
# regular-expression-matching                                    0.840534
# same-tree                                                      0.000000
# minimum-cost-to-merge-stones                                   1.000000
# grid-illumination                                              0.884365
# ...                                                                 ...
# minimum-number-of-k-consecutive-bit-flips                      0.897370
# number-of-squareful-arrays                                     0.886814
# find-the-town-judge                                            0.864439
# maximum-binary-tree-ii                                         0.873303
# available-captures-for-rook                                    0.866757
#
#                                            grid-illumination  \
# two-sum                                             0.864339
# regular-expression-matching                         0.848167
# same-tree                                           0.000000
# minimum-cost-to-merge-stones                        0.884365
# grid-illumination                                   1.000000
# ...                                                      ...
# minimum-number-of-k-consecutive-bit-flips           0.887779
# number-of-squareful-arrays                          0.872419
# find-the-town-judge                                 0.891561
# maximum-binary-tree-ii                              0.899063
# available-captures-for-rook                         0.853852
#
#                                            find-common-characters  \
# two-sum                                                  0.927714
# regular-expression-matching                              0.912762
# same-tree                                                0.000000
# minimum-cost-to-merge-stones                             0.840507
# grid-illumination                                        0.828887
# ...                                                           ...
# minimum-number-of-k-consecutive-bit-flips                0.890102
# number-of-squareful-arrays                               0.869704
# find-the-town-judge                                      0.803245
# maximum-binary-tree-ii                                   0.850834
# available-captures-for-rook                              0.742720
#
#                                            check-if-word-is-valid-after-substitutions  \
# two-sum                                                                      0.883680
# regular-expression-matching                                                  0.912532
# same-tree                                                                    0.000000
# minimum-cost-to-merge-stones                                                 0.831024
# grid-illumination                                                            0.843550
# ...                                                                               ...
# minimum-number-of-k-consecutive-bit-flips                                    0.894897
# number-of-squareful-arrays                                                   0.888505
# find-the-town-judge                                                          0.840025
# maximum-binary-tree-ii                                                       0.915702
# available-captures-for-rook                                                  0.746199
#
#                                            max-consecutive-ones-iii  \
# two-sum                                                    0.932714
# regular-expression-matching                                0.907472
# same-tree                                                  0.000000
# minimum-cost-to-merge-stones                               0.877274
# grid-illumination                                          0.850859
# ...                                                             ...
# minimum-number-of-k-consecutive-bit-flips                  0.942432
# number-of-squareful-arrays                                 0.929309
# find-the-town-judge                                        0.808819
# maximum-binary-tree-ii                                     0.879805
# available-captures-for-rook                                0.763630
#
#                                            maximize-sum-of-array-after-k-negations  \
# two-sum                                                                   0.941823
# regular-expression-matching                                               0.900435
# same-tree                                                                 0.000000
# minimum-cost-to-merge-stones                                              0.903316
# grid-illumination                                                         0.881308
# ...                                                                            ...
# minimum-number-of-k-consecutive-bit-flips                                 0.948633
# number-of-squareful-arrays                                                0.926274
# find-the-town-judge                                                       0.852248
# maximum-binary-tree-ii                                                    0.910571
# available-captures-for-rook                                               0.793056
#
#                                            clumsy-factorial  ...  \
# two-sum                                                 0.0  ...
# regular-expression-matching                             0.0  ...
# same-tree                                               0.0  ...
# minimum-cost-to-merge-stones                            0.0  ...
# grid-illumination                                       0.0  ...
# ...                                                     ...  ...
# minimum-number-of-k-consecutive-bit-flips               0.0  ...
# number-of-squareful-arrays                              0.0  ...
# find-the-town-judge                                     0.0  ...
# maximum-binary-tree-ii                                  0.0  ...
# available-captures-for-rook                             0.0  ...
#
#                                            satisfiability-of-equality-equations  \
# two-sum                                                                0.918070
# regular-expression-matching                                            0.924634
# same-tree                                                              0.000000
# minimum-cost-to-merge-stones                                           0.868253
# grid-illumination                                                      0.878815
# ...                                                                         ...
# minimum-number-of-k-consecutive-bit-flips                              0.900891
# number-of-squareful-arrays                                             0.909331
# find-the-town-judge                                                    0.859747
# maximum-binary-tree-ii                                                 0.898291
# available-captures-for-rook                                            0.777696
#
#                                            broken-calculator  \
# two-sum                                             0.912370
# regular-expression-matching                         0.872154
# same-tree                                           0.000000
# minimum-cost-to-merge-stones                        0.892897
# grid-illumination                                   0.891041
# ...                                                      ...
# minimum-number-of-k-consecutive-bit-flips           0.922578
# number-of-squareful-arrays                          0.893504
# find-the-town-judge                                 0.860112
# maximum-binary-tree-ii                              0.883450
# available-captures-for-rook                         0.823507
#
#                                            subarrays-with-k-different-integers  \
# two-sum                                                               0.914368
# regular-expression-matching                                           0.869125
# same-tree                                                             0.000000
# minimum-cost-to-merge-stones                                          0.898991
# grid-illumination                                                     0.890252
# ...                                                                        ...
# minimum-number-of-k-consecutive-bit-flips                             0.942147
# number-of-squareful-arrays                                            0.941777
# find-the-town-judge                                                   0.841439
# maximum-binary-tree-ii                                                0.896083
# available-captures-for-rook                                           0.803742
#
#                                            cousins-in-binary-tree  \
# two-sum                                                  0.861026
# regular-expression-matching                              0.846004
# same-tree                                                0.000000
# minimum-cost-to-merge-stones                             0.845793
# grid-illumination                                        0.857257
# ...                                                           ...
# minimum-number-of-k-consecutive-bit-flips                0.876943
# number-of-squareful-arrays                               0.866009
# find-the-town-judge                                      0.850852
# maximum-binary-tree-ii                                   0.886525
# available-captures-for-rook                              0.781644
#
#                                            rotting-oranges  \
# two-sum                                           0.893720
# regular-expression-matching                       0.850359
# same-tree                                         0.000000
# minimum-cost-to-merge-stones                      0.905554
# grid-illumination                                 0.909108
# ...                                                    ...
# minimum-number-of-k-consecutive-bit-flips         0.905513
# number-of-squareful-arrays                        0.856419
# find-the-town-judge                               0.882097
# maximum-binary-tree-ii                            0.868519
# available-captures-for-rook                       0.854266
#
#                                            minimum-number-of-k-consecutive-bit-flips  \
# two-sum                                                                     0.921225
# regular-expression-matching                                                 0.895335
# same-tree                                                                   0.000000
# minimum-cost-to-merge-stones                                                0.897370
# grid-illumination                                                           0.887779
# ...                                                                              ...
# minimum-number-of-k-consecutive-bit-flips                                   1.000000
# number-of-squareful-arrays                                                  0.931069
# find-the-town-judge                                                         0.849734
# maximum-binary-tree-ii                                                      0.915021
# available-captures-for-rook                                                 0.802484
#
#                                            number-of-squareful-arrays  \
# two-sum                                                      0.910534
# regular-expression-matching                                  0.889189
# same-tree                                                    0.000000
# minimum-cost-to-merge-stones                                 0.886814
# grid-illumination                                            0.872419
# ...                                                               ...
# minimum-number-of-k-consecutive-bit-flips                    0.931069
# number-of-squareful-arrays                                   1.000000
# find-the-town-judge                                          0.826660
# maximum-binary-tree-ii                                       0.904263
# available-captures-for-rook                                  0.773799
#
#                                            find-the-town-judge  \
# two-sum                                               0.834872
# regular-expression-matching                           0.837857
# same-tree                                             0.000000
# minimum-cost-to-merge-stones                          0.864439
# grid-illumination                                     0.891561
# ...                                                        ...
# minimum-number-of-k-consecutive-bit-flips             0.849734
# number-of-squareful-arrays                            0.826660
# find-the-town-judge                                   1.000000
# maximum-binary-tree-ii                                0.881366
# available-captures-for-rook                           0.849263
#
#                                            maximum-binary-tree-ii  \
# two-sum                                                  0.885692
# regular-expression-matching                              0.896396
# same-tree                                                0.000000
# minimum-cost-to-merge-stones                             0.873303
# grid-illumination                                        0.899063
# ...                                                           ...
# minimum-number-of-k-consecutive-bit-flips                0.915021
# number-of-squareful-arrays                               0.904263
# find-the-town-judge                                      0.881366
# maximum-binary-tree-ii                                   1.000000
# available-captures-for-rook                              0.794289
#
#                                            available-captures-for-rook
# two-sum                                                       0.767589
# regular-expression-matching                                   0.766480
# same-tree                                                     0.000000
# minimum-cost-to-merge-stones                                  0.866757
# grid-illumination                                             0.853852
# ...                                                                ...
# minimum-number-of-k-consecutive-bit-flips                     0.802484
# number-of-squareful-arrays                                    0.773799
# find-the-town-judge                                           0.849263
# maximum-binary-tree-ii                                        0.794289
# available-captures-for-rook                                   1.000000
#
# [3103 rows x 3103 columns]

# %%
new_df.to_csv('../data/content-similarity.csv')

# %%
import pandas as pd
df = pd.read_csv('../data/content-similarity.csv').set_index('Unnamed: 0')

# %%
df
# Out:
#                                             two-sum  \
# Unnamed: 0
# two-sum                                    1.000000
# regular-expression-matching                0.895608
# same-tree                                  0.000000
# minimum-cost-to-merge-stones               0.888748
# grid-illumination                          0.864339
# ...                                             ...
# minimum-number-of-k-consecutive-bit-flips  0.921225
# number-of-squareful-arrays                 0.910534
# find-the-town-judge                        0.834872
# maximum-binary-tree-ii                     0.885692
# available-captures-for-rook                0.767589
#
#                                            regular-expression-matching  \
# Unnamed: 0
# two-sum                                                       0.895608
# regular-expression-matching                                   1.000000
# same-tree                                                     0.000000
# minimum-cost-to-merge-stones                                  0.840534
# grid-illumination                                             0.848167
# ...                                                                ...
# minimum-number-of-k-consecutive-bit-flips                     0.895335
# number-of-squareful-arrays                                    0.889189
# find-the-town-judge                                           0.837857
# maximum-binary-tree-ii                                        0.896396
# available-captures-for-rook                                   0.766480
#
#                                            same-tree  \
# Unnamed: 0
# two-sum                                          0.0
# regular-expression-matching                      0.0
# same-tree                                        0.0
# minimum-cost-to-merge-stones                     0.0
# grid-illumination                                0.0
# ...                                              ...
# minimum-number-of-k-consecutive-bit-flips        0.0
# number-of-squareful-arrays                       0.0
# find-the-town-judge                              0.0
# maximum-binary-tree-ii                           0.0
# available-captures-for-rook                      0.0
#
#                                            minimum-cost-to-merge-stones  \
# Unnamed: 0
# two-sum                                                        0.888748
# regular-expression-matching                                    0.840534
# same-tree                                                      0.000000
# minimum-cost-to-merge-stones                                   1.000000
# grid-illumination                                              0.884365
# ...                                                                 ...
# minimum-number-of-k-consecutive-bit-flips                      0.897370
# number-of-squareful-arrays                                     0.886814
# find-the-town-judge                                            0.864439
# maximum-binary-tree-ii                                         0.873303
# available-captures-for-rook                                    0.866757
#
#                                            grid-illumination  \
# Unnamed: 0
# two-sum                                             0.864339
# regular-expression-matching                         0.848167
# same-tree                                           0.000000
# minimum-cost-to-merge-stones                        0.884365
# grid-illumination                                   1.000000
# ...                                                      ...
# minimum-number-of-k-consecutive-bit-flips           0.887779
# number-of-squareful-arrays                          0.872419
# find-the-town-judge                                 0.891561
# maximum-binary-tree-ii                              0.899063
# available-captures-for-rook                         0.853852
#
#                                            find-common-characters  \
# Unnamed: 0
# two-sum                                                  0.927714
# regular-expression-matching                              0.912762
# same-tree                                                0.000000
# minimum-cost-to-merge-stones                             0.840507
# grid-illumination                                        0.828887
# ...                                                           ...
# minimum-number-of-k-consecutive-bit-flips                0.890102
# number-of-squareful-arrays                               0.869704
# find-the-town-judge                                      0.803245
# maximum-binary-tree-ii                                   0.850834
# available-captures-for-rook                              0.742720
#
#                                            check-if-word-is-valid-after-substitutions  \
# Unnamed: 0
# two-sum                                                                      0.883680
# regular-expression-matching                                                  0.912532
# same-tree                                                                    0.000000
# minimum-cost-to-merge-stones                                                 0.831024
# grid-illumination                                                            0.843550
# ...                                                                               ...
# minimum-number-of-k-consecutive-bit-flips                                    0.894897
# number-of-squareful-arrays                                                   0.888505
# find-the-town-judge                                                          0.840025
# maximum-binary-tree-ii                                                       0.915702
# available-captures-for-rook                                                  0.746199
#
#                                            max-consecutive-ones-iii  \
# Unnamed: 0
# two-sum                                                    0.932714
# regular-expression-matching                                0.907472
# same-tree                                                  0.000000
# minimum-cost-to-merge-stones                               0.877274
# grid-illumination                                          0.850859
# ...                                                             ...
# minimum-number-of-k-consecutive-bit-flips                  0.942432
# number-of-squareful-arrays                                 0.929309
# find-the-town-judge                                        0.808819
# maximum-binary-tree-ii                                     0.879805
# available-captures-for-rook                                0.763630
#
#                                            maximize-sum-of-array-after-k-negations  \
# Unnamed: 0
# two-sum                                                                   0.941823
# regular-expression-matching                                               0.900435
# same-tree                                                                 0.000000
# minimum-cost-to-merge-stones                                              0.903316
# grid-illumination                                                         0.881308
# ...                                                                            ...
# minimum-number-of-k-consecutive-bit-flips                                 0.948633
# number-of-squareful-arrays                                                0.926274
# find-the-town-judge                                                       0.852248
# maximum-binary-tree-ii                                                    0.910571
# available-captures-for-rook                                               0.793056
#
#                                            clumsy-factorial  ...  \
# Unnamed: 0                                                   ...
# two-sum                                                 0.0  ...
# regular-expression-matching                             0.0  ...
# same-tree                                               0.0  ...
# minimum-cost-to-merge-stones                            0.0  ...
# grid-illumination                                       0.0  ...
# ...                                                     ...  ...
# minimum-number-of-k-consecutive-bit-flips               0.0  ...
# number-of-squareful-arrays                              0.0  ...
# find-the-town-judge                                     0.0  ...
# maximum-binary-tree-ii                                  0.0  ...
# available-captures-for-rook                             0.0  ...
#
#                                            satisfiability-of-equality-equations  \
# Unnamed: 0
# two-sum                                                                0.918070
# regular-expression-matching                                            0.924634
# same-tree                                                              0.000000
# minimum-cost-to-merge-stones                                           0.868253
# grid-illumination                                                      0.878815
# ...                                                                         ...
# minimum-number-of-k-consecutive-bit-flips                              0.900891
# number-of-squareful-arrays                                             0.909331
# find-the-town-judge                                                    0.859747
# maximum-binary-tree-ii                                                 0.898291
# available-captures-for-rook                                            0.777696
#
#                                            broken-calculator  \
# Unnamed: 0
# two-sum                                             0.912370
# regular-expression-matching                         0.872154
# same-tree                                           0.000000
# minimum-cost-to-merge-stones                        0.892897
# grid-illumination                                   0.891041
# ...                                                      ...
# minimum-number-of-k-consecutive-bit-flips           0.922578
# number-of-squareful-arrays                          0.893504
# find-the-town-judge                                 0.860112
# maximum-binary-tree-ii                              0.883450
# available-captures-for-rook                         0.823507
#
#                                            subarrays-with-k-different-integers  \
# Unnamed: 0
# two-sum                                                               0.914368
# regular-expression-matching                                           0.869125
# same-tree                                                             0.000000
# minimum-cost-to-merge-stones                                          0.898991
# grid-illumination                                                     0.890252
# ...                                                                        ...
# minimum-number-of-k-consecutive-bit-flips                             0.942147
# number-of-squareful-arrays                                            0.941777
# find-the-town-judge                                                   0.841439
# maximum-binary-tree-ii                                                0.896083
# available-captures-for-rook                                           0.803742
#
#                                            cousins-in-binary-tree  \
# Unnamed: 0
# two-sum                                                  0.861026
# regular-expression-matching                              0.846004
# same-tree                                                0.000000
# minimum-cost-to-merge-stones                             0.845793
# grid-illumination                                        0.857257
# ...                                                           ...
# minimum-number-of-k-consecutive-bit-flips                0.876943
# number-of-squareful-arrays                               0.866009
# find-the-town-judge                                      0.850852
# maximum-binary-tree-ii                                   0.886525
# available-captures-for-rook                              0.781644
#
#                                            rotting-oranges  \
# Unnamed: 0
# two-sum                                           0.893720
# regular-expression-matching                       0.850359
# same-tree                                         0.000000
# minimum-cost-to-merge-stones                      0.905554
# grid-illumination                                 0.909108
# ...                                                    ...
# minimum-number-of-k-consecutive-bit-flips         0.905513
# number-of-squareful-arrays                        0.856419
# find-the-town-judge                               0.882097
# maximum-binary-tree-ii                            0.868519
# available-captures-for-rook                       0.854266
#
#                                            minimum-number-of-k-consecutive-bit-flips  \
# Unnamed: 0
# two-sum                                                                     0.921225
# regular-expression-matching                                                 0.895335
# same-tree                                                                   0.000000
# minimum-cost-to-merge-stones                                                0.897370
# grid-illumination                                                           0.887779
# ...                                                                              ...
# minimum-number-of-k-consecutive-bit-flips                                   1.000000
# number-of-squareful-arrays                                                  0.931069
# find-the-town-judge                                                         0.849734
# maximum-binary-tree-ii                                                      0.915021
# available-captures-for-rook                                                 0.802484
#
#                                            number-of-squareful-arrays  \
# Unnamed: 0
# two-sum                                                      0.910534
# regular-expression-matching                                  0.889189
# same-tree                                                    0.000000
# minimum-cost-to-merge-stones                                 0.886814
# grid-illumination                                            0.872419
# ...                                                               ...
# minimum-number-of-k-consecutive-bit-flips                    0.931069
# number-of-squareful-arrays                                   1.000000
# find-the-town-judge                                          0.826660
# maximum-binary-tree-ii                                       0.904263
# available-captures-for-rook                                  0.773799
#
#                                            find-the-town-judge  \
# Unnamed: 0
# two-sum                                               0.834872
# regular-expression-matching                           0.837857
# same-tree                                             0.000000
# minimum-cost-to-merge-stones                          0.864439
# grid-illumination                                     0.891561
# ...                                                        ...
# minimum-number-of-k-consecutive-bit-flips             0.849734
# number-of-squareful-arrays                            0.826660
# find-the-town-judge                                   1.000000
# maximum-binary-tree-ii                                0.881366
# available-captures-for-rook                           0.849263
#
#                                            maximum-binary-tree-ii  \
# Unnamed: 0
# two-sum                                                  0.885692
# regular-expression-matching                              0.896396
# same-tree                                                0.000000
# minimum-cost-to-merge-stones                             0.873303
# grid-illumination                                        0.899063
# ...                                                           ...
# minimum-number-of-k-consecutive-bit-flips                0.915021
# number-of-squareful-arrays                               0.904263
# find-the-town-judge                                      0.881366
# maximum-binary-tree-ii                                   1.000000
# available-captures-for-rook                              0.794289
#
#                                            available-captures-for-rook
# Unnamed: 0
# two-sum                                                       0.767589
# regular-expression-matching                                   0.766480
# same-tree                                                     0.000000
# minimum-cost-to-merge-stones                                  0.866757
# grid-illumination                                             0.853852
# ...                                                                ...
# minimum-number-of-k-consecutive-bit-flips                     0.802484
# number-of-squareful-arrays                                    0.773799
# find-the-town-judge                                           0.849263
# maximum-binary-tree-ii                                        0.794289
# available-captures-for-rook                                   1.000000
#
# [3103 rows x 3103 columns]

# %%
df['grid-illumination'] + df['two-sum']
# Out:
# Unnamed: 0
# two-sum                                      1.864339
# regular-expression-matching                  1.743775
# same-tree                                    0.000000
# minimum-cost-to-merge-stones                 1.773114
# grid-illumination                            1.864339
#                                                ...
# minimum-number-of-k-consecutive-bit-flips    1.809004
# number-of-squareful-arrays                   1.782953
# find-the-town-judge                          1.726433
# maximum-binary-tree-ii                       1.784755
# available-captures-for-rook                  1.621441
# Length: 3103, dtype: float64

# %%
df['grid-illumination']
# Out:
# Unnamed: 0
# two-sum                                      0.864339
# regular-expression-matching                  0.848167
# same-tree                                    0.000000
# minimum-cost-to-merge-stones                 0.884365
# grid-illumination                            1.000000
#                                                ...
# minimum-number-of-k-consecutive-bit-flips    0.887779
# number-of-squareful-arrays                   0.872419
# find-the-town-judge                          0.891561
# maximum-binary-tree-ii                       0.899063
# available-captures-for-rook                  0.853852
# Name: grid-illumination, Length: 3103, dtype: float64

# %%
df['two-sum']
# Out:
# Unnamed: 0
# two-sum                                      1.000000
# regular-expression-matching                  0.895608
# same-tree                                    0.000000
# minimum-cost-to-merge-stones                 0.888748
# grid-illumination                            0.864339
#                                                ...
# minimum-number-of-k-consecutive-bit-flips    0.921225
# number-of-squareful-arrays                   0.910534
# find-the-town-judge                          0.834872
# maximum-binary-tree-ii                       0.885692
# available-captures-for-rook                  0.767589
# Name: two-sum, Length: 3103, dtype: float64

# %%
last_5 = ['two-sum', 'grid-illumination']
sum = df[last_5[0]]
count = 1
for i in range(1, len(last_5)):
    if last_5[i] in df:
        sum += df[last_5[i]]
        count += 1

sum /= count

# %%
sum.nlargest(10)
# Out:
# Unnamed: 0
# grid-illumination                                    1.432170
# plates-between-candles                               1.395622
# mark-elements-on-array-by-performing-queries         1.394351
# minimum-edge-weight-equilibrium-queries-in-a-tree    1.392595
# cycle-length-queries-in-a-tree                       1.390480
# prison-cells-after-n-days                            1.389458
# earliest-second-to-mark-indices-i                    1.388731
# sliding-window-median                                1.388575
# number-of-islands-ii                                 1.388159
# find-maximal-uncovered-ranges                        1.387342
# Name: two-sum, dtype: float64
